# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Загрузка данных из репозитория

# %%
# train
train = pd.read_csv('https://github.com/Quantanomo/data_sets/raw/master/CAX_MortgageModeling_Train.csv')
train.head(2)
# Out:
#      Unique_ID  MORTGAGE NUMBER  PROPERTY VALUE  MORTGAGE PAYMENT    GDS  \
# 0  CAX_Train_1                1          900000              5429  61.98
# 1  CAX_Train_2                2          386000              2179  35.22
#
#      LTV    TDS  AMORTIZATION  MORTGAGE AMOUNT  RATE   ...      PROPERTY TYPE  \
# 0  65.00  71.63           360        1040000.0   4.0   ...    Single Detached
# 1  74.29  40.65           360         390000.0   4.5   ...    Single Detached
#
#   TERM  FSA    AGE RANGE GENDER  INCOME INCOME TYPE  NAICS CODE  CREDIT SCORE  \
# 0   12  L4C     Under 25   Male  108000           8       44-45           681
# 1   12  L9T  70 and over   Male   78000           2          56           710
#
#    RESULT
# 0  FUNDED
# 1  FUNDED
#
# [2 rows x 22 columns]

# %%
# test
test = pd.read_csv('https://github.com/Quantanomo/data_sets/raw/master/CAX_MortgageModeling_Test.csv')
test.head()
# Out:
#     Unique_ID  MORTGAGE NUMBER  PROPERTY VALUE  MORTGAGE PAYMENT    GDS  \
# 0  CAX_Test_1            45643          430000              1861  34.51
# 1  CAX_Test_2            45644          676000              1032  37.18
# 2  CAX_Test_3            45645          418000               949  23.30
# 3  CAX_Test_4            45646          693000              3059  42.45
# 4  CAX_Test_5            45647          324000              1554  42.97
#
#      LTV    TDS  AMORTIZATION  MORTGAGE AMOUNT  RATE  ...      PROPERTY TYPE  \
# 0  75.00  35.60           360         322500.0  4.25  ...          High Rise
# 1  55.51  37.50           360         375000.0  5.00  ...      Semi-Detached
# 2  79.90  32.88           360         334000.0  4.75  ...    Single Detached
# 3  80.00  42.59           360         554400.0  4.25  ...    Single Detached
# 4  75.00  43.48           360         243000.0  4.00  ...    Single Detached
#
#   TERM  FSA  AGE RANGE  GENDER INCOME INCOME TYPE  NAICS CODE  CREDIT SCORE  \
# 0   24  M9B      45-49    Male  76000           8          23           834
# 1   12  M3N      55-59  Female  75000           2          56           804
# 2   60  K2H      30-34    Male  70000           8          72           730
# 3   24  L3R   Under 25  Female  90000           2       44-45           786
# 4   12  L2S      35-39    Male  48000           2          56           787
#
#   RESULT
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 22 columns]

# %%
train.dtypes
# Out:
# Unique_ID             object
# MORTGAGE NUMBER        int64
# PROPERTY VALUE         int64
# MORTGAGE PAYMENT       int64
# GDS                  float64
# LTV                  float64
# TDS                  float64
# AMORTIZATION           int64
# MORTGAGE AMOUNT      float64
# RATE                 float64
# MORTGAGE PURPOSE      object
# PAYMENT FREQUENCY     object
# PROPERTY TYPE         object
# TERM                   int64
# FSA                   object
# AGE RANGE             object
# GENDER                object
# INCOME                 int64
# INCOME TYPE            int64
# NAICS CODE            object
# CREDIT SCORE           int64
# RESULT                object
# dtype: object

# %%
# Переименую колонки для удобного обращения к ним

train = train.rename(columns = {
    'MORTGAGE NUMBER': 'MORTGAGE_NUMBER',
    'PROPERTY VALUE': 'PROPERTY_VALUE',
    'MORTGAGE PAYMENT': 'MORTGAGE_PAYMENT',
    'MORTGAGE PURPOSE': 'MORTGAGE_PURPOSE',
    'PAYMENT FREQUENCY': 'PAYMENT_FREQUENCY',
    'MORTGAGE AMOUNT': 'MORTGAGE_AMOUNT',
    'PROPERTY TYPE': 'PROPERTY_TYPE',
    'AGE RANGE': 'AGE_RANGE',
    'INCOME TYPE': 'INCOME_TYPE',
    'NAICS CODE': 'NAICS_CODE',
    'CREDIT SCORE': 'CREDIT_SCORE'
})

train.head(2)
# Out:
#      Unique_ID  MORTGAGE_NUMBER  PROPERTY_VALUE  MORTGAGE_PAYMENT    GDS  \
# 0  CAX_Train_1                1          900000              5429  61.98
# 1  CAX_Train_2                2          386000              2179  35.22
#
#      LTV    TDS  AMORTIZATION  MORTGAGE_AMOUNT  RATE   ...      PROPERTY_TYPE  \
# 0  65.00  71.63           360        1040000.0   4.0   ...    Single Detached
# 1  74.29  40.65           360         390000.0   4.5   ...    Single Detached
#
#   TERM  FSA    AGE_RANGE GENDER  INCOME INCOME_TYPE  NAICS_CODE  CREDIT_SCORE  \
# 0   12  L4C     Under 25   Male  108000           8       44-45           681
# 1   12  L9T  70 and over   Male   78000           2          56           710
#
#    RESULT
# 0  FUNDED
# 1  FUNDED
#
# [2 rows x 22 columns]

# %%
test = test.rename(columns = {
    'MORTGAGE NUMBER': 'MORTGAGE_NUMBER',
    'PROPERTY VALUE': 'PROPERTY_VALUE',
    'MORTGAGE PAYMENT': 'MORTGAGE_PAYMENT',
    'MORTGAGE AMOUNT': 'MORTGAGE_AMOUNT',
    'MORTGAGE PURPOSE': 'MORTGAGE_PURPOSE',
    'PAYMENT FREQUENCY': 'PAYMENT_FREQUENCY',
    'PROPERTY TYPE': 'PROPERTY_TYPE',
    'AGE RANGE': 'AGE_RANGE',
    'INCOME TYPE': 'INCOME_TYPE',
    'NAICS CODE': 'NAICS_CODE',
    'CREDIT SCORE': 'CREDIT_SCORE'
})

test.head(2)
# Out:
#     Unique_ID  MORTGAGE_NUMBER  PROPERTY_VALUE  MORTGAGE_PAYMENT    GDS  \
# 0  CAX_Test_1            45643          430000              1861  34.51
# 1  CAX_Test_2            45644          676000              1032  37.18
#
#      LTV   TDS  AMORTIZATION  MORTGAGE_AMOUNT  RATE  ...    PROPERTY_TYPE  \
# 0  75.00  35.6           360         322500.0  4.25  ...        High Rise
# 1  55.51  37.5           360         375000.0  5.00  ...    Semi-Detached
#
#   TERM  FSA  AGE_RANGE  GENDER INCOME INCOME_TYPE  NAICS_CODE  CREDIT_SCORE  \
# 0   24  M9B      45-49    Male  76000           8          23           834
# 1   12  M3N      55-59  Female  75000           2          56           804
#
#   RESULT
# 0    NaN
# 1    NaN
#
# [2 rows x 22 columns]

# %%
# Зависимый признак RESULT перекодирую в 1,0
train = pd.concat([train, pd.get_dummies(train['RESULT'], prefix ='RESULT')], axis=1)

train = train.drop(['RESULT', 'RESULT_NOT FUNDED'], axis=1)
train.head(2)
# Out:
#      Unique_ID  MORTGAGE_NUMBER  PROPERTY_VALUE  MORTGAGE_PAYMENT    GDS  \
# 0  CAX_Train_1                1          900000              5429  61.98
# 1  CAX_Train_2                2          386000              2179  35.22
#
#      LTV    TDS  AMORTIZATION  MORTGAGE_AMOUNT  RATE      ...       \
# 0  65.00  71.63           360        1040000.0   4.0      ...
# 1  74.29  40.65           360         390000.0   4.5      ...
#
#      PROPERTY_TYPE TERM  FSA    AGE_RANGE GENDER  INCOME INCOME_TYPE  \
# 0  Single Detached   12  L4C     Under 25   Male  108000           8
# 1  Single Detached   12  L9T  70 and over   Male   78000           2
#
#    NAICS_CODE  CREDIT_SCORE RESULT_FUNDED
# 0       44-45           681             1
# 1          56           710             1
#
# [2 rows x 22 columns]

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Посмотрю на размерность данных

# %%
# Посмотрим на размер данных
train.shape, test.shape
# Out:
# ((45642, 22), (15214, 22))

# %% [markdown]
# Вывод: фреймы одинаковы по своей структуре

# %% [markdown]
# ### Проверю пропущенные значения и посмотрю на тип данных

# %%
# Функция принимает датафрейм и выдает кол-во и процент пропущенных значений и тип данных
def missing_data(data):
    total = data.isnull().sum()
    percent = (data.isnull().sum()/data.isnull().count()*100)
    tt = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    types = []
    for col in data.columns:
        dtype = str(data[col].dtype)
        types.append(dtype)
    tt['Types'] = types
    return(np.transpose(tt))

# train
missing_data(train)
# Out:
#         Unique_ID MORTGAGE_NUMBER PROPERTY_VALUE MORTGAGE_PAYMENT      GDS  \
# Total           0               0              0                0        0
# Percent         0               0              0                0        0
# Types      object           int64          int64            int64  float64
#
#              LTV      TDS AMORTIZATION MORTGAGE_AMOUNT     RATE      ...       \
# Total          0        0            0               0        0      ...
# Percent        0        0            0               0        0      ...
# Types    float64  float64        int64         float64  float64      ...
#
#         PROPERTY_TYPE   TERM     FSA AGE_RANGE  GENDER INCOME INCOME_TYPE  \
# Total               0      0       0         0       0      0           0
# Percent             0      0       0         0       0      0           0
# Types          object  int64  object    object  object  int64       int64
#
#         NAICS_CODE CREDIT_SCORE RESULT_FUNDED
# Total            0            0             0
# Percent          0            0             0
# Types       object        int64         uint8
#
# [3 rows x 22 columns]

# %%
# test
missing_data(test)
# Out:
#         Unique_ID MORTGAGE_NUMBER PROPERTY_VALUE MORTGAGE_PAYMENT      GDS  \
# Total           0               0              0                0        0
# Percent         0               0              0                0        0
# Types      object           int64          int64            int64  float64
#
#              LTV      TDS AMORTIZATION MORTGAGE_AMOUNT     RATE   ...     \
# Total          0        0            0               0        0   ...
# Percent        0        0            0               0        0   ...
# Types    float64  float64        int64         float64  float64   ...
#
#         PROPERTY_TYPE   TERM     FSA AGE_RANGE  GENDER INCOME INCOME_TYPE  \
# Total               0      0       0         0       0      0           0
# Percent             0      0       0         0       0      0           0
# Types          object  int64  object    object  object  int64       int64
#
#         NAICS_CODE CREDIT_SCORE   RESULT
# Total            0            0    15214
# Percent          0            0      100
# Types       object        int64  float64
#
# [3 rows x 22 columns]

# %% [markdown]
# Вывод: Пропущенных значений нет (за исключением искомого значения в тестовом наборе). В наборах присутствуют количественные и номинативные признаки

# %% [markdown]
# ### Посмотрю на характеристики количественных признаков

# %%
# train
train.describe()
# Out:
#        MORTGAGE_NUMBER  PROPERTY_VALUE  MORTGAGE_PAYMENT           GDS  \
# count      45642.00000    4.564200e+04      45642.000000  4.564200e+04
# mean       22821.50000    5.826110e+05       2392.148043  2.138033e+02
# std        13175.85483    4.382082e+05       1688.208721  3.263766e+04
# min            1.00000    1.400000e+04        141.000000 -3.704000e+01
# 25%        11411.25000    3.400000e+05       1406.000000  1.984000e+01
# 50%        22821.50000    4.770000e+05       2033.000000  2.921000e+01
# 75%        34231.75000    6.850000e+05       2866.000000  3.587000e+01
# max        45642.00000    1.800000e+07      46479.000000  6.872300e+06
#
#                 LTV           TDS  AMORTIZATION  MORTGAGE_AMOUNT  \
# count  45642.000000  4.564200e+04  45642.000000     4.564200e+04
# mean      70.632932  4.125670e+02    355.309583     4.255704e+05
# std       11.566444  6.425859e+04     18.011798     3.020469e+05
# min        6.667000 -1.070000e+01     60.000000     1.500000e+04
# 25%       65.000000  3.284000e+01    360.000000     2.459250e+05
# 50%       75.000000  3.830000e+01    360.000000     3.575000e+05
# 75%       80.000000  4.217000e+01    360.000000     5.120000e+05
# max       95.000000  1.346256e+07    480.000000     7.500000e+06
#
#                RATE          TERM        INCOME   INCOME_TYPE  CREDIT_SCORE  \
# count  45642.000000  45642.000000  4.564200e+04  45642.000000  45642.000000
# mean       4.651149     15.286578  1.251093e+05      5.315017    662.662811
# std        0.642371      7.443857  1.149974e+05      3.267761    132.818234
# min        2.500000      6.000000  1.000000e+03     -1.000000      0.000000
# 25%        4.250000     12.000000  6.800000e+04      2.000000    623.000000
# 50%        4.500000     12.000000  9.700000e+04      6.000000    677.000000
# 75%        5.000000     12.000000  1.450000e+05      8.000000    736.000000
# max       10.000000     60.000000  3.860000e+06     20.000000    899.000000
#
#        RESULT_FUNDED
# count   45642.000000
# mean        0.789251
# std         0.407845
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
# test
test.describe()
# Out:
#        MORTGAGE_NUMBER  PROPERTY_VALUE  MORTGAGE_PAYMENT           GDS  \
# count     15214.000000    1.521400e+04      15214.000000  1.521400e+04
# mean      53249.500000    5.790442e+05       2384.620350  2.306921e+03
# std        4392.047833    4.175277e+05       1608.625935  1.933853e+05
# min       45643.000000    3.600000e+04        208.000000 -4.878000e+01
# 25%       49446.250000    3.370000e+05       1397.000000  1.997000e+01
# 50%       53249.500000    4.740000e+05       2025.000000  2.930000e+01
# 75%       57052.750000    6.800000e+05       2850.000000  3.610000e+01
# max       60856.000000    7.500000e+06      25032.000000  2.138046e+07
#
#                 LTV           TDS  AMORTIZATION  MORTGAGE_AMOUNT  \
# count  15214.000000  1.521400e+04  15214.000000     1.521400e+04
# mean      70.748041  2.754330e+03    355.208361     4.237224e+05
# std       11.580747  2.092715e+05     18.421023     2.898901e+05
# min        6.900000 -4.204000e+01    120.000000     3.338800e+02
# 25%       65.000000  3.293000e+01    360.000000     2.441450e+05
# 50%       75.000000  3.836000e+01    360.000000     3.562500e+05
# 75%       80.000000  4.222000e+01    360.000000     5.111850e+05
# max       93.325000  2.274796e+07    480.000000     4.760000e+06
#
#                RATE          TERM        INCOME   INCOME_TYPE  CREDIT_SCORE  \
# count  15214.000000  15214.000000  1.521400e+04  15214.000000   15214.00000
# mean       4.643010     15.405022  1.241874e+05      5.324438     663.11680
# std        0.633511      7.531778  1.110122e+05      3.303275     133.94336
# min        2.500000      6.000000  1.000000e+03     -1.000000       0.00000
# 25%        4.250000     12.000000  6.700000e+04      2.000000     624.00000
# 50%        4.500000     12.000000  9.700000e+04      6.000000     678.00000
# 75%        5.000000     12.000000  1.440000e+05      8.000000     736.00000
# max       10.000000     60.000000  2.125000e+06     19.000000     899.00000
#
#        RESULT
# count     0.0
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %% [markdown]
# MORTGAGE NUMBER (Номер ипотеки) - ни о чем нам не говорит. Судя по номерам, я исследую 2/3 (train) и 1/3 (test) одного датафрейма (номера ипотек с 1 по 60856)
#
# PROPERTY VALUE (Стоимость имущества) - Среднее, медиана и sd в наборах примерно одинаковы
#
# MORTGAGE PAYMENT (Выплата по ипотеке) - Среднее, медиана и sd в наборах примерно одинаковы
#
# GDS (Годовые расходы на жилье / Годовой доход) - Медианы одинаковы, средние и sd различны
#
# LTV (сумма ипотеки / оценочная стоимость недвижимости) - Среднее, медиана и sd в наборах примерно одинаковы
#
# TDS (Все годовые расходы / Годовой доход) - Схоже по параметрам с GDS
#
# AMORTIZATION (Амортизация в месяцах) - Амортизация в наборах одинакова
#
# MORTGAGE AMOUNT	(Сумма ипотеки в $) - Среднее, медиана и sd в наборах примерно одинаковы
#
# RATE (Процентная ставка) - Ставки в наборах равны
#
# TERM (Срок ипотеки) - Сроки ипотеки одинаковы
#
# INCOME (Доходы) - Доходы одинаковы
#
# INCOME TYPE (Тип дохода) - Это статусы занятости (номинативная переменная)
#
# CREDIT SCORE (Рейтинг кредитного бюро) - рейтинги в наборах похожи
#
# ----------- НОМИНАТИВНЫЕ ПРИЗНАКИ
#
# PROPERTY TYPE (Тип недвижимости)
#
# FSA (Почтовый индекс)
#
# MORTGAGE PURPOSE (Цель ипотеки)
#
# PAYMENT FREQUENCY (Частота платежей)
#
# AGE RANGE (Возрастная категория)
#
# GENDER (Пол)
#
# NAICS CODE (Категория работы)

# %% [markdown]
# ### Посмотрю на распределения номинативных признаков

# %% [markdown]
# #### INCOME TYPE (Тип дохода)

# %%
train.groupby('INCOME_TYPE')['Unique_ID'].nunique()
# Out:
# INCOME_TYPE
# -1       123
#  1       186
#  2     19525
#  3       749
#  4        79
#  5       579
#  6      1693
#  7       191
#  8     21724
#  9        76
#  10       21
#  11       38
#  12       95
#  13        1
#  14        3
#  15       47
#  16       19
#  17       74
#  18        7
#  19      410
#  20        2
# Name: Unique_ID, dtype: int64

# %%
sns.countplot(train['INCOME_TYPE'])

# %% [markdown]
# #### PROPERTY TYPE (Тип недвижимости)

# %%
train.groupby('PROPERTY_TYPE')['Unique_ID'].nunique()
# Out:
# PROPERTY_TYPE
# Duplex                     469
# Fourplex                   118
# High Rise                 5909
# Semi-Detached             4227
# Single Detached          29377
# Townhouse Condominium     2309
# Townhouse Freehold        3040
# Triplex                    193
# Name: Unique_ID, dtype: int64

# %%
sns.countplot(train['PROPERTY_TYPE'])

# %% [markdown]
# #### FSA (Почтовый индекс)

# %%
sns.countplot(train['FSA'])

# %% [markdown]
# #### MORTGAGE PURPOSE (Цель ипотеки)

# %%
train.groupby('MORTGAGE_PURPOSE')['Unique_ID'].nunique()
# Out:
# MORTGAGE_PURPOSE
# Purchase     24419
# Refinance    21223
# Name: Unique_ID, dtype: int64

# %%
sns.countplot(train['MORTGAGE_PURPOSE'])

# %% [markdown]
# #### PAYMENT FREQUENCY (Частота платежей)

# %%
train.groupby('PAYMENT_FREQUENCY')['Unique_ID'].nunique()
# Out:
# PAYMENT_FREQUENCY
# Bi-Weekly                 1803
# Bi-Weekly Accelerated     1047
# Monthly                  42785
# Semi-Monthly                 4
# Weekly                       2
# Weekly Accelerated           1
# Name: Unique_ID, dtype: int64

# %%
sns.countplot(train['PAYMENT_FREQUENCY'])

# %% [markdown]
# #### AGE RANGE (Возрастная категория)

# %%
train.groupby('AGE_RANGE')['Unique_ID'].nunique()
# Out:
# AGE_RANGE
# 25-29          2534
# 30-34          4551
# 35-39          5818
# 40-44          6877
# 45-49          7645
# 50-54          6801
# 55-59          4710
# 60-64          2816
# 65-69          1678
# 70 and over    1374
# Under 25        838
# Name: Unique_ID, dtype: int64

# %%
sns.countplot(train['AGE_RANGE'])

# %% [markdown]
# #### GENDER (Пол)

# %%
train.groupby('GENDER')['Unique_ID'].nunique()
# Out:
# GENDER
# Female     14375
# Male       24849
# Unknown     6418
# Name: Unique_ID, dtype: int64

# %%
sns.countplot(train['GENDER'])

# %% [markdown]
# #### NAICS CODE (Категория работы)

# %%
train.groupby('NAICS_CODE')['Unique_ID'].nunique()
# Out:
# NAICS_CODE
# 11         304
# 22          63
# 23        5092
# 31-33      982
# 42          98
# 44-45     3622
# 48-49     3305
# 51         145
# 52        1022
# 53        2473
# 54        5326
# 55         246
# 56       11245
# 61        1382
# 62        2166
# 71         640
# 72        2722
# 81        4296
# 92         513
# Name: Unique_ID, dtype: int64

# %%
sns.countplot(train['NAICS_CODE'])

# %% [markdown]
# #### RESULT

# %%
train.groupby('RESULT_FUNDED')['Unique_ID'].nunique()
# Out:
# RESULT_FUNDED
# 0     9619
# 1    36023
# Name: Unique_ID, dtype: int64

# %%
sns.countplot(train['RESULT_FUNDED'])

# %% [markdown]
# Выводы:
# ВАЖНО! в GENDER есть нераспознанные значения - их нужно будет заменить. Как? (вижу варианты: заменить случайно в пропорциях, либо попытаться предсказать, либо удалить)
#
# Закодируй номинативные признаки, в т.ч. тот что попал в int

# %% [markdown]
# ### Посмотрю на корреляцию признаков

# %%
corr = train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col0 {
#             background-color:  #b40426;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col1 {
#             background-color:  #5470de;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col2 {
#             background-color:  #5673e0;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col3 {
#             background-color:  #3d50c3;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col4 {
#             background-color:  #7597f6;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col5 {
#             background-color:  #3d50c3;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col6 {
#             background-color:  #6384eb;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col7 {
#             background-color:  #5b7ae5;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col8 {
#             background-color:  #7da0f9;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col9 {
#             background-color:  #506bda;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col10 {
#             background-color:  #4c66d6;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col11 {
#             background-color:  #4a63d3;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col12 {
#             background-color:  #7ea1fa;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row0_col13 {
#             background-color:  #5470de;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col0 {
#             background-color:  #3e51c5;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col1 {
#             background-color:  #b40426;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col2 {
#             background-color:  #da5a49;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col3 {
#             background-color:  #4055c8;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col4 {
#             background-color:  #5e7de7;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col5 {
#             background-color:  #4055c8;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col6 {
#             background-color:  #81a4fb;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col7 {
#             background-color:  #d75445;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col8 {
#             background-color:  #6f92f3;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col9 {
#             background-color:  #3d50c3;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col10 {
#             background-color:  #e0dbd8;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col11 {
#             background-color:  #7ea1fa;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col12 {
#             background-color:  #9bbcff;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row1_col13 {
#             background-color:  #3c4ec2;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col0 {
#             background-color:  #3e51c5;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col1 {
#             background-color:  #da5a49;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col2 {
#             background-color:  #b40426;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col3 {
#             background-color:  #3f53c6;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col4 {
#             background-color:  #97b8ff;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col5 {
#             background-color:  #3f53c6;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col6 {
#             background-color:  #82a6fb;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col7 {
#             background-color:  #c32e31;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col8 {
#             background-color:  #7a9df8;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col9 {
#             background-color:  #3b4cc0;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col10 {
#             background-color:  #ebd3c6;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col11 {
#             background-color:  #81a4fb;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col12 {
#             background-color:  #9abbff;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row2_col13 {
#             background-color:  #3b4cc0;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col0 {
#             background-color:  #3b4cc0;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col1 {
#             background-color:  #5470de;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col2 {
#             background-color:  #5572df;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col3 {
#             background-color:  #b40426;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col4 {
#             background-color:  #6f92f3;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col5 {
#             background-color:  #b70d28;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col6 {
#             background-color:  #6282ea;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col7 {
#             background-color:  #5a78e4;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col8 {
#             background-color:  #80a3fa;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col9 {
#             background-color:  #4f69d9;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col10 {
#             background-color:  #465ecf;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col11 {
#             background-color:  #4b64d5;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col12 {
#             background-color:  #7ea1fa;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row3_col13 {
#             background-color:  #5470de;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col0 {
#             background-color:  #3e51c5;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col1 {
#             background-color:  #3c4ec2;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col2 {
#             background-color:  #7a9df8;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col3 {
#             background-color:  #3b4cc0;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col4 {
#             background-color:  #b40426;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col5 {
#             background-color:  #3b4cc0;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col6 {
#             background-color:  #93b5fe;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col7 {
#             background-color:  #89acfd;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col8 {
#             background-color:  #485fd1;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col9 {
#             background-color:  #4961d2;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col10 {
#             background-color:  #7093f3;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col11 {
#             background-color:  #485fd1;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col12 {
#             background-color:  #a9c6fd;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row4_col13 {
#             background-color:  #6687ed;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row5_col0 {
#             background-color:  #3b4cc0;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row5_col1 {
#             background-color:  #5470de;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row5_col2 {
#             background-color:  #5572df;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row5_col3 {
#             background-color:  #b70d28;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row5_col4 {
#             background-color:  #6f92f3;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row5_col5 {
#             background-color:  #b40426;
#         }    #T_5da55e74_70bc_11e9_8d9e_7085c2834447row5_co

# %%
# Посмотрю топ отрицательных корреляций
corr.unstack().sort_values().drop_duplicates().head()
# Out:
# CREDIT_SCORE     RATE               -0.265223
# LTV              RATE               -0.210382
# AMORTIZATION     RATE               -0.145285
# MORTGAGE_AMOUNT  RATE               -0.108087
# RESULT_FUNDED    MORTGAGE_PAYMENT   -0.087540
# dtype: float64

# %%
# Посмотрю топ положительных корреляций
corr.unstack().sort_values(ascending=False).drop_duplicates().head(9)
# Out:
# RESULT_FUNDED     RESULT_FUNDED       1.000000
# TDS               GDS                 0.990829
# MORTGAGE_AMOUNT   MORTGAGE_PAYMENT    0.956259
# PROPERTY_VALUE    MORTGAGE_AMOUNT     0.887418
# MORTGAGE_PAYMENT  PROPERTY_VALUE      0.876000
# MORTGAGE_AMOUNT   INCOME              0.549262
# INCOME            MORTGAGE_PAYMENT    0.540807
# PROPERTY_VALUE    INCOME              0.491104
# INCOME_TYPE       INCOME              0.216430
# dtype: float64

# %% [markdown]
# Выводы:
#
# Высокая корреляция между:
#
# PROPERTY VALUE (Стоимость имущества) и MORTGAGE PAYMENT (Выплата по ипотеке)
#
# PROPERTY VALUE (Стоимость имущества) и MORTGAGE AMOUNT (Сумма ипотеки в $)
#
# MORTGAGE AMOUNT (Сумма ипотеки в $) и MORTGAGE PAYMENT (Выплата по ипотеке)
#
# GDS (Годовые расходы на жилье / Годовой доход) и TDS (Все годовые расходы / Годовой доход)
#
# Также INCOME (Доходы) положительно коррелируют с MORTGAGE AMOUNT / MORTGAGE PAYMENT / PROPERTY VALUE
#
# Сильной отрицательной корреляции не обнаружил
#
# С зависимой переменной ничего не коррелирует

# %%
# Посмотрю на распределения количественных признаков
sns.pairplot(train)
